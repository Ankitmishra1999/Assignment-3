# %%
Q.1 explain with an example each when to use a for loop and a while loop.

Ans. for loop example:- 

digits = [0, 1, 5]
for i in digits:
    print(i)
else:
    print("No items left.")
    
while loop example:- 
   
    number = int(input("enter your number"))
    factorial =1

while number > 0 :
    factorial = factorial*number
    number = number-1
factorial

# %%
Q.2  write a python programe to print the sum and 
    product of the first 10 natural numbers using for and while loop. 
    
Ans. for loop:-
    
    sum = 0 
    for i in range(1, 11): 
    sum += i 
     print(sum)

while loop:-

     n = int(input("enter a number: "))
     i = 1
    sum = 0
    while (i <= n):
    sum = sum + i
    i = i + 1
    print("The sum is: ", sum)

# %%
Q.3 create a python programme to compute the electricity bill for a household.
  the per unit charges in rupees ase as follows: for the first 100 units , the user will be charged rs.4.5per unit,
    for the next 100 units ,the user will be charged Rs.6per unit, and for the next 100 units ,
    the user will be charged Rs.10 per unit , and above the user will be charged Rs.20per unit. 
    
ans.
    unit = int(input("Enter your unit: "))
if unit <= 100:
    bill = unit * 4.5
elif unit >= 101 and unit <= 200:
    bill =  unit * 6
elif unit >= 201 and unit <= 300:
    bill = unit * 10
else:
    bill = unit * 20
print("Bill Per Unit:",bill)

# %%
Q.4 Create a list of numbers from 1 to 100. Use for loop and while loop to calculate the cube of each
number and if the cube of that number is divisible by 4 or 5 then append that number in a list and print
that list.

ans. Using a for loop:
    
cubes_list = []

for num in range(1, 101):
    cube = num ** 3
    if cube % 4 == 0 or cube % 5 == 0:
        cubes_list.append(num)

print(cubes_list)    


2. Using a while loop:

cubes_list = []
num = 1

while num <= 100:
    cube = num ** 3
    if cube % 4 == 0 or cube % 5 == 0:
        cubes_list.append(num)
    num += 1

print(cubes_list)

# %%
Q.5  Write a program to filter count vowels in the below-given string.
string = "I want to become a data scientist"

ans. 

string = "I want to become a data scientist"
vowels = ['a', 'e', 'i', 'o', 'u']
count = 0

for char in string:
    if char.lower() in vowels:
        count += 1

print("Number of vowels:", count)
